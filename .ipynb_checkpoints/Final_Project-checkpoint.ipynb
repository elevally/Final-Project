# %% [markdown]
# # The Importance of Drag
#
# # Eric LeVally
#
# ## Introduction
# In physics we are often first taught basic kinematics.  This means we are taught about the physics behind a ball being thrown, the friction between a tire and asphalt, elastic and inelastic collisions, and so on.  Let us narrow our view of basic kinematics to those of a projectile in motion.  More specifically lets look at deadly projectiles.  The first deadly projectile can be traced back to the stone age, when hunting with spears and arrows was key to survival.  A simple arrow is good for understanding the basics, but does not deal with many modern issues.  A much more common projectile nowadays is an intercontinental ballistic missile or IBM.  An IBM flying through the air can be considered a driven projectile in motion. Because of the height and distance that modern day missiles can travel, the basic equations and models for a projectile are not accurate enough, especially if we wanted to intercept one of these such missiles before it were to hit its target.  In these situations, the quantification of uncertainty is vital to success. Using very approximate methods to model the trajectories of IBMs can result in devastatingly wrong outputs. This code will be modeling the trajectory of an IBM.  More specifically, the Titan II ballistic missile.  The Titan II was developed in June of 1963 and was in used until June of 1987.  It was approximately 31.4 meters tall, could reach a height of 185 kilometers above the Earth's surface, could travel up to 15,000 kilometers, had a max speed of about 6,706 meters per second, and could be launched in about a minute. This project uses the speed, distance, and height that the Titan II could reach to model the physics behind intercepting an incoming IBM (foe) with our own IBM (friend). [3][4][5]

# %% [markdown]
# ## Mathematical Model
#
# A missile propels itself by ejecting ignited fuel in the opposite direction of desired motion.  Other than this driving force, the only other forces acting on the missile that I will be modelling are the forces caused by the acceleration of gravity, and the drag force.  Both of these forces, in some way, depend on altitude.  The gravitational acceleration at any given distance from the center of the Earth is given by the equation:
#
# $$g = GM/r^{2}$$
#
# where G is the gravitational constant $6.67408 \times 10^{-11}m^{3}kg^{-1}s^{-2}$, M is the mass of the Earth in kilograms ($5.972 \times 10^{24}kg$), and r is the distance between the center of the Earth and the object in meters.  The magnitude of the drag force is given by the equation
#
# $$\vec{F}_{drag} \approx -C\rho A \upsilon^{2} \hat{\upsilon}$$ [1]
#
# where C is the drag coefficient, $\rho$ is the density of the air, A is the frontal area of the object, and $\upsilon$ is the velocity of the object.  This equation depends on the density of the air, which we know has different values at different altitudes.  The density of the air at a given altitude is given by the equation
#
# $$\rho = \rho_{0} e^{(-y/y_{0})}$$ [1]
# where y is the altitude, $y_{0} = 1.0 x 10^{4}m$ and $\rho_{0}$ is the density at sea level (y=0).  This gives us that the drag force due to air resistance is actually
# $$F^{*}_{drag} = \frac{\rho}{\rho_{0}}F_{drag}(y=0)$$ In this equation, $F^{*}_{drag}$ is the force due to the air drag at the current altitude. [1]

# %% [markdown]
# ## Numerical Methods
#
# Euler's method is used in the calculation of the trajectories of the missiles.  Euler's method allows us to approximate values for a solution of a differential equation.  So long as we are given a starting value x at some t, then we can write the value of x a short interval $h$ later using a Taylor expansion.  So we have that: $x(t+h) = x(t) + h\frac{dx}{dt} + \frac{1}{2}h^{2}\frac{d^{2}x}{dt^{2}} +...$ which gives us $x(t+h) = hf(x,t) + O(h^{2})$ where $O(h^{2})$ is a shorthand for all of the terms that go as $h^{2}$ and higher.  If $h$ is small, then $h^{2}$ is significantly smaller, and can be ignored.  This allows us to toss out $O(h^{2})$ and leaves us with the following equation. [1]
# $$ x(t+h) = x(t) + hf(x,t) $$
# So long as h remains small enough, we can see fairly accurate solutions to our differential equations.  This means that the relevant controlling equations are those of a projectile.  Using the Euler method, the x position is
#
# $$  x_{i+1} = x_{i} + v_{x,i}\Delta t$$  Where $x_{i+1}$ is the x value at the current step, $x_{i}$ is the x value at the previous step, $v_{x,i}$ is the current x component of the velocity, and $\Delta t$ is the change in time between steps. [1]
#
# $$  v_{x,i+1} =  v_{x,i}$$ Where $v_{x,i+1}$ is the current x component of the velocity and $v_{x,i}$ is the previous x component of the velocity.  The velocity in the x direction remains constant since there is no drag force acting on the projectile. [1]
#
# $$  y_{i+1} = y_{i} + v_{y,i}\Delta t$$  Where $y_{i+1}$ is the y value at the current step, $y_{i}$ is the y value at the previous step, and $v_{y,i}$ is the current y component of the velocity. [1]
#
# $$  v_{y,i+1} =  v_{y,i} - g\Delta t$$  Where $v_{y,i+1}$ is the current y component of the velocity, $v_{y,i}$ is now the previous y component of the velocity, and $g$ is the acceleration of gravity.  This model allows us to plot the location of our friend and foe missiles as they travel towards each other.  So long as there is no drag force.  If drag force is not neglected, then we add $$- \frac{B_{2}vv_{xy, i}}{m} \delta t $$ to each of our equations of velocity.  From this we get the equations
# $$  v_{x,i+1} =  v_{x,i}- \frac{B_{2}vv_{x, i}}{m} \delta t $$ and
# $$  v_{y,i+1} =  v_{y,i} - g\Delta t - \frac{B_{2}vv_{y, i}}{m} \delta t $$
#
# This means that the x component of the velocity is no longer constant. [1]
#
# The Runge-Kutta method is used to calculate the height of an object, given a velocity, in the shooting method code.  The Runge-Kutta method is a taylor series approximation of the solution, where there is an initial value problem defined as $\dot x = f(t,y), (t_{0}) = y_{0}$.  In this model x is an unknown function of time.  The derivative of x ($\dot x$) is a function of x and t.  The initial x value is $x_{0}$ and is found at time $t_{0}$.  With a step size h which is greater than zero, we can define the equation $x_{n+1} = x_{n} + \frac{1}{6}(k_{1} +2k_{2} +2k_{3} +k_{4})$. Where $k_{1}$ is the increment of the approximation which is based on the slope at the beginning of the interval, $k_{2}$ is the increment of the approximation which is based on the slope at the mid-point of the interval using $k_{1}$, $k_{3}$ is again the increment at the mid-point, but is using $k_{2}$, and $k_{4}$ is the increment of the approximation at the end of the interval using $k_{3}$. [2]
#
# The bisection method is used in the shooting method code to essentially guess a velocity needed.  The bisection method works by finding the roots of a nonlinear eqaution for a single variable.  A nonlinear equation can be rearanged so that all of its terms are on one side of the equation, and so it can be written in the form $f(x) = 0$.  When we find the solution to such an equation, we find its root.  This method uses an interval specified by the user, and finds the solution, so long as it is contained somewhere in the given interval.  The method works by first choosing a pair of points $x_{1}$ and $x_{2}$ and checking that $f(x_{1}$ and $f(x_{2})$ have opposite signs.  Second, we calculate te midpoint between the the two points ($x^{\prime}$), and evaluate our function at that point.  If f($x^{\prime}$) has the same sign as $x_{1}$, then $x_{1}$ now equals $x^{\prime}$.  If they have opposite signs, then $x_{2}$ now equals $x^{\prime}$.  If   $\big | x_{1} - x_{2} \big |$ is greater than the target accuracy, then we repeat the procces from the second step until it is. [1][2]
#
# The shooting method outputs the required components of the velocity to reach a given position at a given time.  The shooting method is a trial-and-error method that searches for correct values of initial conditions that give answers that match a given set of boundary conditions.  It starts by guessing some initial value for one of the initial conditions, and then checking if the output matches our boundart conditions.  If not, the program runs again until it finds the initial conditions required to give us our boundary conditions.  The shooting method used in the code below combines the Fourth Order Runge-Kutta method and Bisection method in order to solve for the velocities of our friendly projectile. [1]
#
#
# For this model, the parameters will be that the initial velocity of each projectile will be 6,706 m/s. The firing angles will be a minimum of 20 degrees and a maximum of 125 degrees with respect to the origin.  The initial height of the missiles will be at least sea level, and at most 10 kilometers above sea level.  This means that a missile cannot be fired from underwater or underground.
# A missile will be coming at us at a random angle, and the program will calculate and output the correct angle and speed that the friendly intercepting missile will need to fire at in order to intercept the incoming missile before it can reach the ground. The output of the program should be the counter attack trajectory.

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Shooting Method Code

# %%
def velocity_components(tFinal, xFinal, yFinal, drag_constant, drag = False):
    
    '''Uses the input values to calculate the x and y components of velocity for the friendly projectile
    necessary to reach the given point at the given time.
    
    Inputs:
    tFinal = the final time 
    yFinal = the final y position of the projectile
    xFinal = the final x position of the projectile
    
    Outputs:
    vx = the v component of the velocity necessary to reach the given point at the given time
    vy = the y component of the velocit necessary to reach the given point at the given time'''

    # Constants defined
    g = 9.81 # The acceleration due to gravity in m/s^s
    a = 0.0
    b = tFinal  # Amount of time passed in seconds
    N = 1000 # Number of Runge-Kutta steps
    h = (b-a)/N
    target = 1e-1 # Target accuracy
    
    if drag == False:

        def f(r):
            x = r[0]
            y = r[1]
            fx = y
            fy = -g
            return np.array([fx,fy],float)

        # The Fourth Order Runge-Kutta Method
        def height(v):

            '''Function that solves the equation and calculates the final height using the Runge-Kutta method.

            Input:
            v = the guessed velocity

            Output: 
            r[0] = the final height
            '''
            r = np.array([-yFinal,v],float)
            for t in np.arange(a,b,h):
                k1 = h*f(r)
                k2 = h*f(r+0.5*k1)
                k3 = h*f(r+0.5*k2)
                k4 = h*f(r+k3)
                r += (k1+2*k2+2*k3+k4)/6

            return r[0]

        v1 = 0.01 
        v2 = 10000.0
        h1 = height(v1)
        h2 = height(v2)

        while abs(h2-h1)>target:
            vp = (v1+v2)/2
            hp = height(vp)
            if h1*hp>yFinal:  # final height of the projectile
                v1 = vp
                h1 = hp

            else:
                v2 = vp
                h2 = hp

        vy = (v1+v2)/2
        vx = xFinal/tFinal
        
        return(vx, vy)
    
    if drag == True:
        x = 0
        y = 0       
        deltaT = 1
        
        def position(vy, vx):
            Fdrag = drag_constant*y_velocity**2
            
            for i in range(1,tFinal,deltaT):
                vmag = math.sqrt(vx**2 + vy**2)
                Fdrag_y = Fdrag*(vy/vmag)
                Fdrag_x = Fdrag*(vx/vmag)
                vy = vy - g*delta_t - (Fdrag_y)*delta_t
                vx = vx - (Fdrag_x)*delta_t
                y += vy*deltaT
                
            return(y, x)
            
         
        v1y = 0.01 
        v2y = 10000.0
        v1x = v1y
        v2x = v2y
        p1y, p1x = position(v1y, v1x)
        p2y, p2x = position(v2y, v2x)

        while abs(p2y-p1y)>target or abs(p2x-p1x)>target:
            vpy = (v1y+v2y)/2
            vpx = (v1x+v2x)/2
            hpy, hpx = position(vpy, vpx)
            if p1y*hpy>yFinal:   # final height of the projectile
                v1y = vpy
                h1y = hpy
                
            elif p1x*hpx>xFinal:
                v1x = vpx
                h1x = hpx 

            else:
                v2y = vpy
                h2y = hpy
                v2x = vpx
                h2x = hpx

        vy = (v1y+v2y)/2
        vx = (v1x+v2x)/2
        
        return(vx,vy)

# %% [markdown]
# ## Friendly Firing Parameters Code

# %%
def firing_parameters(vx, vy):
    
    '''Takes the given inputs and outputs the magnitude and angle that the friendly projectile must be fired at in order to
    hit the enemy projectile
    
    Inputs:
    vx = the x component of the velocity of our friendly projectile
    vy = the y component of the velocity of our friendly projectile
    
    Outputs:
    velocity = the magnitude of the velocity of our friendly projectile
    angle_degrees = the angle at which our friendly projectile should be fired
    
    Example:
    >>> firing_parameters(3,4)
    (5.0, 53.13010235415599)'''
    
    velocity = math.sqrt(vx**2 + vy**2)
    angle_radians = math.acos(vx/velocity)
    angle_degrees = 180/math.pi*angle_radians
    
    print("The magnitude of the velocity should be: ", velocity)
    print("The firing angle should be: ", angle_degrees)
    return(velocity,angle_degrees)

# %% [markdown]
# ## Friend or Foe Projectile Motion Code

# %%
def projectile(theta, v0, deltaT, tFinal, fof, drag_constant, y0 = 0, x0 = 0, drag = False):
    
    '''Takes the inputs to calculate and plot the x and y coordinates of a projectile at a given time.
    
    Inputs:
    y0 = the initial y posisition of the projectile
    x0 = the initial x position of the projectile
    theta = the angle in degrees that the projectile is fired at
    v0 = the initial velocity that the projectile is fired at
    deltaT = the time between measurements
    tFinal = the given final time
    fof = friend or foe
    
    Outputs:
    Plots the x and y coordinates of the projectile, and returns its x and y position at t final
    '''
    
    # Constants Defined
    g = 9.81
    theta = math.pi/180*theta
    
    # Initial x and y components and values set and stored
    x = []
    y = []
    x.append(x0)
    y.append(y0)
    vx = v0*math.cos(theta)
    vy = v0*math.sin(theta)
    
    if drag == False:

        # Euler Method
        for i in np.arange(1,tFinal,1):

            # Euler equations for x and y position values
            x.append(x[i-1] + vx*deltaT)
            y.append(y[i-1] + vy*deltaT)

            # Euler equations for x and y velocity values
            vx = vx
            vy = vy -g*deltaT       
            
    if drag == True:
        
        for i in range(1,tFinal,1):
            x.append(x[i-1] + vx*deltaT)
            y.append(y[i-1] + vy*deltaT)
            vmag = math.sqrt(vx**2 + vy**2)
            Fdrag = drag_constant*vmag**2
            Fdrag_x = Fdrag*(vx/vmag)
            Fdrag_y = Fdrag*(vy/vmag)

            # This is where the new velocities are calculated
            vy = vy - g*deltaT - (Fdrag_y)*deltaT
            vx = vx -  (Fdrag_x)*deltaT     
     
    plt.ylim(0,1.5e5)
    plt.xlim(0,1e5)
    if fof == "friend":
        plt.plot(x,y,label="Friend")   
    elif fof == "foe":
        plt.plot(x,y,label="Foe")
    plt.ylabel("y(m)")
    plt.xlabel("x(m)")
    plt.title("Projectile Motion of Freindly and Foe Missiles")
    plt.legend()

    #print("Final x position = ", x[tFinal-1],"Final y position = ", y[tFinal-1])
    return(x[tFinal-1], y[tFinal-1])

# %%
fig=plt.figure(figsize=(15, 7), dpi= 80, facecolor='w', edgecolor='k')

tFinal = 200
drag_constant = 4*(10**-5)
xFinal, yFinal = projectile(125, 6706, 1, tFinal, "foe", drag_constant, y0 = 5e4, x0 = 1e5,drag = True)
vx, vy = velocity_components(tFinal, xFinal, yFinal, drag_constant)
v0,theta = firing_parameters(vx, vy)
projectile(theta, v0, 1, tFinal, "friend",drag_constant, y0 = 0, x0 = 0)

tFinal = 200
drag_constant = 4*(10**-5)
xFinal, yFinal = projectile(125, 6706, 1, tFinal, "foe", drag_constant, y0 = 5e4, x0 = 1e5,drag = False)
vx, vy = velocity_components(tFinal, xFinal, yFinal, drag_constant)
v0,theta = firing_parameters(vx, vy)
projectile(theta, v0, 1, tFinal, "friend",drag_constant, y0 = 0, x0 = 0)
# Out:
# The magnitude of the velocity should be:  1241.411967665371
# The firing angle should be:  80.1611106606666
# The magnitude of the velocity should be:  6622.224208062675
# The firing angle should be:  120.16057248447525
# (-662107.1412875983, 946149.9637920673)

# %% [markdown]
# ## Results and Analysis
# The plot above shows the trajectories of four projectiles.  The enemy projectiles (Blue and Red lines), which are both given an initial firing angle of 35 degrees with respect to the horizontal, and are fired with an initial velocity of 6,706 meters per second.  The green line coming fromt he left side, and a friendly IBM.  The blue line coming from the right is the enemy projectile it is meant to intercept.  The friendly projectile is fired from the origin (0,0) and intercepts the the enemy projectile at a distance of about 42,000 meters from the origin, and a height of about 50,000 meters.  These two IBMs are modeled with drag forces.  The red line coming from the right is the enemy projectile with the same initial velocity, firing angle, and time to interception, but it is modeled without the drag forces. It is clear from the above plot that factoring in the drag forces due to air resistance is vital to being able to approximate the trajectory of an incoming IBM.  The red line (modeling the projectile without air resistance) manages to travel past the firing point of the friendly projectile.  If drag were to be ignored, it is clear that our friendly missile would be too far off of its mark to intercept the enemy missile.

# %%
fig=plt.figure(figsize=(15, 7), dpi= 80, facecolor='w', edgecolor='k')

tFinal = 150
drag_constant = 4*(10**-5)
xFinal, yFinal = projectile(135, 6706, 1, tFinal, "foe", drag_constant, y0 = 5e4, x0 = 1e5,drag = True)
vx, vy = velocity_components(tFinal, xFinal, yFinal, drag_constant)
v0,theta = firing_parameters(vx, vy)
projectile(theta, v0, 1, tFinal, "friend",drag_constant, y0 = 0, x0 = 0)

tFinal = 150
drag_constant = 5*(10**-5)
xFinal, yFinal = projectile(135, 6706, 1, tFinal, "foe", drag_constant, y0 = 5e4, x0 = 1e5,drag = True)
vx, vy = velocity_components(tFinal, xFinal, yFinal, drag_constant)
v0,theta = firing_parameters(vx, vy)
projectile(theta, v0, 1, tFinal, "friend",drag_constant, y0 = 0, x0 = 0)
# Out:
# The magnitude of the velocity should be:  1169.7481780682401
# The firing angle should be:  78.79989467292299
# The magnitude of the velocity should be:  1134.7879181663934
# The firing angle should be:  74.54597896960517
# (45054.80672627544, 54805.061436666336)

# %% [markdown]
# ## Results and Analysis
#
# In the plot above, two sets of intercepting missiles are modeled.  The initial firing parameters for the foe IBMs are identical.  They are both fired with an angle of 45 degrees with the respect to the horizontal.  They are both fired with an intitial velocity of 6,706 meters per second.  The only difference between the enemy IBMs is that their drag constants are different.  For the first projectile (blue), the drag constant is $4x10^{-5}$. In order to intercept the enemy projectile 150 seconds after being detected, our IBM needs to be fired at an angle of approximately 79 degrees, with a velocity of 1,170 meters per second.  If the drag force constant is increased to $5x10^{-5}$, then the friendly IBM would need to be fired at an angle of approximately 75 degrees, with a velocity of approximately 1134 meters per second.  With these slight changes, the two missiles are intercepted kilometers appart.  The first enemy projectile is intercepted at a height of approximately 60 kilometers, with an x position approximately 35 kilometers from the origin.  The second enemy projectile is intercepted at a height of approximately 55 kilometers, and an x position approximatley 45 kilometers from the origin.  This means that a small change to the drag force constant used in the models, can change the interception point by 5 kilometers in the y direction, and 10 kilometers in the x direction.

# %%
fig=plt.figure(figsize=(15, 7), dpi= 80, facecolor='w', edgecolor='k')

tFinal = 200
drag_constant = 4*(10**-5)
xFinal, yFinal = projectile(125, 6706, 1, tFinal, "foe", drag_constant, y0 = 6e4, x0 = 1e5,drag = True)
vx, vy = velocity_components(tFinal, xFinal, yFinal, drag_constant)
v0,theta = firing_parameters(vx, vy)
projectile(theta, v0, 1, tFinal, "friend",drag_constant, y0 = 0, x0 = 0)

tFinal = 150
drag_constant = 4*(10**-5)
xFinal, yFinal = projectile(125, 6706, 1, tFinal, "foe", drag_constant, y0 = 6e4, x0 = 1e5,drag = True)
vx, vy = velocity_components(tFinal, xFinal, yFinal, drag_constant)
v0,theta = firing_parameters(vx, vy)
projectile(theta, v0, 1, tFinal, "friend",drag_constant, y0 = 0, x0 = 0)
# Out:
# The magnitude of the velocity should be:  1290.150920490178
# The firing angle should be:  80.5362881613927
# The magnitude of the velocity should be:  1318.4971741900588
# The firing angle should be:  76.90079392202864
# (44524.37578322012, 83179.056500143)

# %% [markdown]
# ## Results and Analysis
#
# The plot above shows two sets of intercepting projectiles.  Both sets use the same firing parameters (the foe missile is detected to be coming in at an angle of 35 degrees with respect to the horizontal, and is traveling with a velocity of 6,706 meters per second.  The only difference is that one set intercepts 200 seconds after detection, and the other intercepts 150 seconds after detection.  For the first set (red and ligt blue), the foe missile is intercepted 150 seconds after being detected.  It is intercepted at a height of approximately 80 kilometers, and a distance of approximately 45 kilometers from the firing point.  For the second set (green and blue), the foe missile is intercepted 200 seconds after the the foe IBM is detected.  The foe IBM is intercepted at a heihgt of approximately 55 kilometers.  The foe IBM is intercepted approximately 45 kilometers from where the intercepting missile is fired.  If it takes an extra 50 seconds for the missile to be intercepted, it makes it almost 5 kilometers closer to the x position of its target, and manages to get 20 kilometers closer to the ground. If the missile is allowed to travel for only 50 more seconds before it is intercepted, it can get that much closer to its target.  Clearly every second counts when it comes to intercepting Intercontinental Ballistic Missiles.

# %% [markdown]
# ## Scientific Summary
# In the code above, I modelled the projectile motion of sets of projectiles.  The first projectile being an enemy projectile detected an unknown amount of time after it has been launched.  The code calculates the angle and magnitude of the velocity necessary to intercept the enemy projectile a given time after it has been detected.  After the initial code for the kinematics was completed, code for drag forces was implemented.  This meant that the shooting method function had to be modified so that it could also work for projectiles experiencing drag forces.  So long as the drag constant, position, and trajectory of the enemy projectile are known, the parameters of a friendly projectile can be determined, and the projectile can be fired in order to intercept the incoming IBM. I can further modify this code to add a third dimension, account for the change in air desnity with altitude, the change in the acceleration of gravity as altitude changes, and by implimenting code to account for the coriolis effect.

# %% [markdown]
# ## Personal Summary
# This project allowed me to implement the shooting method, and develp a better understanding of the Euler and 4th order Runge-Kutta methods.  I now have another way to use Euler's method and the 4th order Runge-Kutta method.  This project helped me to understand how difficult it can be to combine several methods that I already know.  I spent more time than I expected on the shooting method code.  If this had not been the case, I would have liked to spend more time implementing code for altitude and gravity.

# %% [markdown]
# ## References
#
# [1] Giordano, Nicholas J, and Hisao Nakanishi. Computational Physics. Dorling Kindersky. 2006
#
# [2] M. E. J. Newman, Computational physics (Createspace, S.l., 2013).
#
# [3] The Titan Missile (U.S. National Park Service). National Parks Service Available at: https://www.nps.gov/articles/titan-icbm.htm. (Accessed: 13th May 2018)
#
# [4] TheMilitaryStandard - Titan II. Williams Air Force Base (AFB), Arizona Available at: http://www.themilitarystandard.com/missile/titan2/specs.php. (Accessed: 13th May 2018)
#
# [5] Titan II. Terrier Oriole Available at: http://www.astronautix.com/t/titanii.html. (Accessed: 13th May 2018)
